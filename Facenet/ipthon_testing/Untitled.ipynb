# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import ipywidgets as widgets
from IPython.display import display
# %matplotlib notebook

# generate test data
x_A = np.random.rand(3)
y_A = np.random.rand(3)
z_A = np.random.rand(3)
# x_A = [np.random.rand(2),

print(x_A)
print(y_A)

print(z_A)


fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111, projection='3d')

ax.plot(x_A[:], y_A[:], z_A[:],'o', markersize=8, color='red', alpha=0.5, label='Abdullah')


# ax.plot(x_B[:,0], x_B[:,1], x_B[:,2],
#             'o', markersize=8, color='green', alpha=0.5, label='Brian')

# # ax.scatter(x, y, z)
# # show plot
plt.show()

def update_plot(x_B,y_B,z_B):
    ax.clear()

    print(x_A,y_A,z_A)
    ax.plot([0.8748608,  0.18117898, 0.24381377], [0.04350022, 0.21508056, 0.52319275], [0.76948669, 0.17724334, 0.61464228],'o', markersize=8, color='red', alpha=0.5, label='Abdullah')
    ax.plot(x_B[:], y_B[:], z_B[:],'o', markersize=8, color='green', alpha=0.5, label='Brian')
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Z axis')
    fig.canvas.draw_idle()

# handle angle 1 update
def update_angle1(value):
    update_plot(angle1 = value['new'])
    angle1_label.value = 'Angle 1 value is: ' + str(value.new)
# Out:
# [0.5004303  0.49715324 0.80572176]
# [0.78093546 0.80921535 0.69535059]
# [0.20741797 0.35719112 0.56455623]
# <img src="data:image/png;base64,..." width="300">

# %%
print('hello')
x_B = np.random.rand(2)
y_B = np.random.rand(2)
z_B = np.random.rand(2)
update_plot(x_B,y_B,z_B)
# Out:
# hello
# [0.5004303  0.49715324 0.80572176] [0.78093546 0.80921535 0.69535059] [0.20741797 0.35719112 0.56455623]
